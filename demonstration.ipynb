# %% [markdown]
# # League of Legends v4.20 Deep Reinforcement Learning Agent
#
# ## Introduction
#
# This Google Colab Notebook is created as a self-contained example for running League of Legends v4.20 DRL training with [pylol](https://github.com/MiscellaneousStuff/pylol) library.
# To use it, simply execute each cell below one by one.

# %% [markdown]
# ## GPU Acceleration
#
# Google Colab provides free Tesla K80 GPU with their environment.
# To enable it, go to **Runtime -> Change Runtime Type** and then choose **GPU** from **Hardware acceleration** choice box.

# %% [markdown]
# ## Installation

# %% [markdown]
# ### GameServer (from source)

# %% [markdown]
# #### Install .NET

# %%
# !wget https://packages.microsoft.com/config/ubuntu/18.04/packages-microsoft-prod.deb -O packages-microsoft-prod.deb
# !sudo dpkg -i packages-microsoft-prod.deb
# Out:
# --2020-11-24 22:58:08--  https://packages.microsoft.com/config/ubuntu/18.04/packages-microsoft-prod.deb
# Resolving packages.microsoft.com (packages.microsoft.com)... 23.99.120.248
# Connecting to packages.microsoft.com (packages.microsoft.com)|23.99.120.248|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3132 (3.1K) [application/octet-stream]
# Saving to: ‘packages-microsoft-prod.deb’
#
# packages-microsoft- 100%[===================>]   3.06K  --.-KB/s    in 0s
#
# 2020-11-24 22:58:08 (109 MB/s) - ‘packages-microsoft-prod.deb’ saved [3132/3132]
#
# Selecting previously unselected package packages-microsoft-prod.
# (Reading database ... 144793 files and directories currently installed.)
# Preparing to unpack packages-microsoft-prod.deb ...
# Unpacking packages-microsoft-prod (1.0-ubuntu18.04.2) ...
# Setting up packages-microsoft-prod (1.0-ubuntu18.04.2) ...

# %% [markdown]
# #### Install the Runtime

# %%
# !sudo apt-get update; \
  sudo apt-get install -y apt-transport-https && \
  sudo apt-get update && \
  sudo apt-get install -y dotnet-sdk-3.1
# Out:
# Get:1 https://packages.microsoft.com/ubuntu/18.04/prod bionic InRelease [4,003 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 Packages [163 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [443 kB]
# Get:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,781 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,690 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,208 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,366 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [54.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [252 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,131 kB]
# Get:24 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [865 kB]
# Get:25 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [46.5 kB]
# Fetched 11.3 MB in 6s (1,763 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 63 not upgraded.
# Need to get 1,692 B of archives.
# After this operation, 153 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 apt-transport-https all 1.6.12ubuntu0.1 [1,692 B]
# Fetched 1,692 B in 1s (2,443 B/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 144801 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_1.6.12ubuntu0.1_all.deb ...
# Unpacking apt-transport-https (1.6.12ubuntu0.1) ...
# Setting up apt-transport-https (1.6.12ubuntu0.1) ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 https://packages.microsoft.com/ubuntu/18.04/prod bionic InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aspnetcore-runtime-3.1 aspnetcore-targeting-pack-3.1 dotnet-apphost-pack-3.1
#   dotnet-host dotnet-hostfxr-3.1 dotnet-runtime-3.1 dotnet-runtime-deps-3.1
#   dotnet-targeting-pack-3.1 netstandard-targeting-pack-2.1
# The following NEW packages will be installed:
#   aspnetcore-runtime-3.1 aspnetcore-targeting-pack-3.1 dotnet-apphost-pack-3.1
#   dotnet-host dotnet-hostfxr-3.1 dotnet-runtime-3.1 dotnet-runtime-deps-3.1
#   dotnet-sdk-3.1 dotnet-targeting-pack-3.1 netstandard-targeting-pack-2.1
# 0 upgraded, 10 newly installed, 0 to remove and 63 not upgraded.
# Need to get 80.6 MB of archives.
# After this operation, 342 MB of additional disk space will be used.
# Get:1 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 dotnet-host amd64 5.0.0-1 [52.9 kB]
# Get:2 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 dotnet-hostfxr-3.1 amd64 3.1.10-1 [121 kB]
# Get:3 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 dotnet-runtime-deps-3.1 amd64 3.1.10-1 [2,682 B]
# Get:4 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 dotnet-runtime-3.1 amd64 3.1.10-1 [21.8 MB]
# Get:5 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 aspnetcore-runtime-3.1 amd64 3.1.10-1 [5,770 kB]
# Get:6 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 dotnet-targeting-pack-3.1 amd64 3.1.0-1 [1,988 kB]
# Get:7 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 aspnetcore-targeting-pack-3.1 amd64 3.1.10-1 [1,063 kB]
# Get:8 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 dotnet-apphost-pack-3.1 amd64 3.1.10-1 [42.4 kB]
# Get:9 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 netstandard-targeting-pack-2.1 amd64 2.1.0-1 [1,476 kB]
# Get:10 https://packages.microsoft.com/ubuntu/18.04/prod bionic/main amd64 dotnet-sdk-3.1 amd64 3.1.404-1 [48.2 MB]
# Fetched 80.6 MB in 2s (49.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 10.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dotnet-host.
# (Reading database ... 144805 files and directories currently installed.)
# Preparing to unpack .../0-dotnet-host_5.0.0-1_amd64.deb ...
# Unpacking dotnet-host (5.0.0-1) ...
# Selecting previously unselected package dotnet-hostfxr-3.1.
# Preparing to unpack .../1-dotnet-hostfxr-3.1_3.1.10-1_amd64.deb ...
# Unpacking dotnet-hostfxr-3.1 (3.1.10-1) ...
# Selecting previously unselected package dotnet-runtime-deps-3.1.
# Preparing to unpack .../2-dotnet-runtime-deps-3.1_3.1.10-1_amd64.deb ...
# Unpacking dotnet-runtime-deps-3.1 (3.1.10-1) ...
# Selecting previously unselected package dotnet-runtime-3.1.
# Preparing to unpack .../3-dotnet-runtime-3.1_3.1.10-1_amd64.deb ...
# Unpacking dotnet-runtime-3.1 (3.1.10-1) ...
# Selecting previously unselected package aspnetcore-runtime-3.1.
# Preparing to unpack .../4-aspnetcore-runtime-3.1_3.1.10-1_amd64.deb ...
# Unpacking aspnetcore-runtime-3.1 (3.1.10-1) ...
# Selecting previously unselected package dotnet-targeting-pack-3.1.
# Preparing to unpack .../5-dotnet-targeting-pack-3.1_3.1.0-1_amd64.deb ...
# Unpacking dotnet-targeting-pack-3.1 (3.1.0-1) ...
# Selecting previously unselected package aspnetcore-targeting-pack-3.1.
# Preparing to unpack .../6-aspnetcore-targeting-pack-3.1_3.1.10-1_amd64.deb ...
# Unpacking aspnetcore-targeting-pack-3.1 (3.1.10-1) ...
# Selecting previously unselected package dotnet-apphost-pack-3.1.
# Preparing to unpack .../7-dotnet-apphost-pack-3.1_3.1.10-1_amd64.deb ...
# Unpacking dotnet-apphost-pack-3.1 (3.1.10-1) ...
# Selecting previously unselected package netstandard-targeting-pack-2.1.
# Preparing to unpack .../8-netstandard-targeting-pack-2.1_2.1.0-1_amd64.deb ...
# Unpacking netstandard-targeting-pack-2.1 (2.1.0-1) ...
# Selecting previously unselected package dotnet-sdk-3.1.
# Preparing to unpack .../9-dotnet-sdk-3.1_3.1.404-1_amd64.deb ...
# Unpacking dotnet-sdk-3.1 (3.1.404-1) ...
# Setting up dotnet-host (5.0.0-1) ...
# Setting up dotnet-apphost-pack-3.1 (3.1.10-1) ...
# Setting up netstandard-targeting-pack-2.1 (2.1.0-1) ...
# Setting up dotnet-runtime-deps-3.1 (3.1.10-1) ...
# Setting up dotnet-targeting-pack-3.1 (3.1.0-1) ...
# Setting up dotnet-hostfxr-3.1 (3.1.10-1) ...
# Setting up dotnet-runtime-3.1 (3.1.10-1) ...
# Setting up aspnetcore-targeting-pack-3.1 (3.1.10-1) ...
# Setting up aspnetcore-runtime-3.1 (3.1.10-1) ...
# Setting up dotnet-sdk-3.1 (3.1.404-1) ...
# This software may collect information about you and your use of the software, and send that to Microsoft.
# Please visit http://aka.ms/dotnet-cli-eula for more information.
# Welcome to .NET Core!
# ---------------------
# Learn more about .NET Core: https://aka.ms/dotnet-docs
# Use 'dotnet --help' to see available commands or visit: https://aka.ms/dotnet-cli-docs
#
# Telemetry
# ---------
# The .NET Core tools collect usage data in order to help us improve your experience. It is collected by Microsoft and shared with the community. You can opt-out of telemetry by setting the DOTNET_CLI_TELEMETRY_OPTOUT environment variable to '1' or 'true' using your favorite shell.
#
# Read more about .NET Core CLI Tools telemetry: https://aka.ms/dotnet-cli-telemetry
#
# Configuring...
# --------------
# A command is running to populate your local package cache to improve restore speed and enable offline access. This command takes up to one minute to complete and only runs once.
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# ### Clone GameServer

# %%
# !rm -rf LeagueSandbox-RL-Learning
# !git clone https://github.com/MiscellaneousStuff/LeagueSandbox-RL-Learning
# !cd LeagueSandbox-RL-Learning && git checkout master && git branch && git submodule init && git submodule update
# Out:
# Cloning into 'LeagueSandbox-RL-Learning'...
# remote: Enumerating objects: 49451, done.
# remote: Counting objects: 100% (49451/49451), done.
# remote: Compressing objects: 100% (11473/11473), done.
# remote: Total 49451 (delta 27201), reused 49379 (delta 27138), pack-reused 0
# Receiving objects: 100% (49451/49451), 11.42 MiB | 6.37 MiB/s, done.
# Resolving deltas: 100% (27201/27201), done.
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# * master
# Submodule 'Content/LeagueSandbox-Default' (https://github.com/LeagueSandbox/LeagueSandbox-Default.git) registered for path 'Content/LeagueSandbox-Default'
# Submodule 'LeaguePackets' (https://github.com/LeagueSandbox/LeaguePackets) registered for path 'LeaguePackets'
# Cloning into '/content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Default'...
# Cloning into '/content/LeagueSandbox-RL-Learning/LeaguePackets'...
# Submodule path 'Content/LeagueSandbox-Default': checked out '9121716e04ed25afb1bcdcb4f16860dfe1d15da1'
# Submodule path 'LeaguePackets': checked out 'fbfcaabb93e1f2da638def87db9d5fc2f537bf9d'

# %% [markdown]
# ### Build GameServer

# %%
# !cd LeagueSandbox-RL-Learning  && dotnet build .
# Out:
# Welcome to .NET Core 3.1!
# ---------------------
# SDK Version: 3.1.404
#
# Telemetry
# ---------
# The .NET Core tools collect usage data in order to help us improve your experience. It is collected by Microsoft and shared with the community. You can opt-out of telemetry by setting the DOTNET_CLI_TELEMETRY_OPTOUT environment variable to '1' or 'true' using your favorite shell.
#
# Read more about .NET Core CLI Tools telemetry: https://aka.ms/dotnet-cli-telemetry
#
# ----------------
# Explore documentation: https://aka.ms/dotnet-docs
# Report issues and find source on GitHub: https://github.com/dotnet/core
# Find out what's new: https://aka.ms/dotnet-whats-new
# Learn about the installed HTTPS developer cert: https://aka.ms/aspnet-core-https
# Use 'dotnet --help' to see available commands or visit: https://aka.ms/dotnet-cli-docs
# Write your first app: https://aka.ms/first-net-core-app
# --------------------------------------------------------------------------------------
# ==Microsoft (R) Build Engine version 16.7.1+52cd83677 for .NET
# Copyright (C) Microsoft Corporation. All rights reserved.
#
# ==  Determining projects to restore...
# /content/LeagueSandbox-RL-Learning/GameServerLibTests/GameServerLibTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
#   Restored /content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj (in 10.27 sec).
#   Restored /content/LeagueSandbox-RL-Learning/GameServerLibTests/GameServerLibTests.csproj (in 10.27 sec).
#   Restored /content/LeagueSandbox-RL-Learning/GameServerCore/GameServerCore.csproj (in 10 ms).
# /content/LeagueSandbox-RL-Learning/PacketDefinitions420/PacketDefinitions420.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
#   Restored /content/LeagueSandbox-RL-Learning/PacketDefinitions420/PacketDefinitions420.csproj (in 6 ms).
#   Restored /content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj (in 2 ms).
# /content/LeagueSandbox-RL-Learning/PacketDefinitionsTests/PacketDefinitionsTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
#   Restored /content/LeagueSandbox-RL-Learning/PacketDefinitionsTests/PacketDefinitionsTests.csproj (in 930 ms).
# /content/LeagueSandbox-RL-Learning/GameServerConsoleTests/GameServerConsoleTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
#   Restored /content/LeagueSandbox-RL-Learning/GameServerConsoleTests/GameServerConsoleTests.csproj (in 2.93 sec).
#   Restored /content/LeagueSandbox-RL-Learning/GameMaths/GameMaths.csproj (in 3 ms).
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
#   Restored /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj (in 69 ms).
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-AI/LeagueSandbox-AI.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
#   Restored /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-AI/LeagueSandbox-AI.csproj (in 71 ms).
# /content/LeagueSandbox-RL-Learning/GameServerConsole/GameServerConsole.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
#   Restored /content/LeagueSandbox-RL-Learning/GameServerConsole/GameServerConsole.csproj (in 2.38 sec).
#   GameServerCore -> /content/LeagueSandbox-RL-Learning/GameServerCore/bin/Debug/netcoreapp3.0/GameServerCore.dll
#   GameMaths -> /content/LeagueSandbox-RL-Learning/GameMaths/bin/Debug/netcoreapp3.0/GameMaths.dll
# /content/LeagueSandbox-RL-Learning/PacketDefinitions420/PacketDefinitions420.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-AI/LeagueSandbox-AI.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3245: Could not resolve this reference. Could not locate the assembly "System". Check to make sure the assembly exists on disk. If this reference is required by your code, you may get compilation errors. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3245: Could not resolve this reference. Could not locate the assembly "System.Core". Check to make sure the assembly exists on disk. If this reference is required by your code, you may get compilation errors. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3245: Could not resolve this reference. Could not locate the assembly "System.Numerics". Check to make sure the assembly exists on disk. If this reference is required by your code, you may get compilation errors. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3243: No way to resolve conflict between "System, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" and "System". Choosing "System, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" arbitrarily. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3243: No way to resolve conflict between "System.Core, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" and "System.Core". Choosing "System.Core, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" arbitrarily. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3243: No way to resolve conflict between "System.Numerics, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" and "System.Numerics". Choosing "System.Numerics, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" arbitrarily. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
#   LeaguePackets -> /content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/bin/Debug/netcoreapp3.0/LeaguePackets.dll
#   PacketDefinitions420 -> /content/LeagueSandbox-RL-Learning/PacketDefinitions420/bin/Debug/netcoreapp3.0/PacketDefinitions420.dll
# /content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# GameObjects/Monster.cs(13,23): warning CS0108: 'Monster.Name' hides inherited member 'Minion.Name'. Use the new keyword if hiding was intended. [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# GameObjects/AttackableUnits/AI/Champion.cs(237,21): warning CS0108: 'Champion.TeleportTo(float, float)' hides inherited member 'ObjAiBase.TeleportTo(float, float)'. Use the new keyword if hiding was intended. [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(928,25): warning CS0649: Field 'Game.Spell_Action.target_player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(944,26): warning CS0649: Field 'Game.Save_Replay_Info.multiplier' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(922,25): warning CS0649: Field 'Game.Attack_Action.target_player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(908,26): warning CS0649: Field 'Game.Move_Action.x' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(942,27): warning CS0649: Field 'Game.Save_Replay_Info.map' is never assigned to, and will always have its default value null [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(936,25): warning CS0649: Field 'Game.Change_Champion_Command.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(907,25): warning CS0649: Field 'Game.Move_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(915,26): warning CS0649: Field 'Game.Teleport_Action.x' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(929,25): warning CS0649: Field 'Game.Spell_Action.spell_slot' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(937,27): warning CS0649: Field 'Game.Change_Champion_Command.champion_name' is never assigned to, and will always have its default value null [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(943,27): warning CS0649: Field 'Game.Save_Replay_Info.players' is never assigned to, and will always have its default value null [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(916,26): warning CS0649: Field 'Game.Teleport_Action.y' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(921,25): warning CS0649: Field 'Game.Attack_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(931,26): warning CS0649: Field 'Game.Spell_Action.y' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(927,25): warning CS0649: Field 'Game.Spell_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(914,25): warning CS0649: Field 'Game.Teleport_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(930,26): warning CS0649: Field 'Game.Spell_Action.x' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(909,26): warning CS0649: Field 'Game.Move_Action.y' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
#   GameServerLib -> /content/LeagueSandbox-RL-Learning/GameServerLib/bin/Debug/netcoreapp3.0/GameServerLib.dll
#   LeagueSandbox-AI -> /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-AI/bin/Debug/netcoreapp3.0/LeagueSandbox-AI.dll
# /content/LeagueSandbox-RL-Learning/PacketDefinitionsTests/PacketDefinitionsTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/GameServerConsoleTests/GameServerConsoleTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/GameServerConsole/GameServerConsole.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
#   PacketDefinitionsTests -> /content/LeagueSandbox-RL-Learning/PacketDefinitionsTests/bin/Debug/netcoreapp3.0/PacketDefinitionsTests.dll
# /content/LeagueSandbox-RL-Learning/GameServerLibTests/GameServerLibTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
#   GameServerLibTests -> /content/LeagueSandbox-RL-Learning/GameServerLibTests/bin/Debug/netcoreapp3.0/GameServerLibTests.dll
# Champions/Ezreal/E.cs(6,7): warning CS0105: The using directive for 'GameServerCore.Domain.GameObjects' appeared previously in this namespace [/content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj]
# Buffs/GangplankE/GangplankE.cs(34,17): warning CS0219: The variable 'time' is assigned but its value is never used [/content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj]
# Buffs/Yasuo/YasuoEBlock.cs(19,23): warning CS0169: The field 'YasuoEBlock._visualBuff' is never used [/content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj]
#   LeagueSandbox-Scripts -> /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/bin/Debug/netcoreapp3.0/LeagueSandbox-Scripts.dll
#   GameServerConsole -> /content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0/GameServerConsole.dll
# ==  GameServerConsoleTests -> /content/LeagueSandbox-RL-Learning/GameServerConsoleTests/bin/Debug/netcoreapp3.0/GameServerConsoleTests.dll
#
# Build succeeded.
#
# /content/LeagueSandbox-RL-Learning/GameServerLibTests/GameServerLibTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/PacketDefinitions420/PacketDefinitions420.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/PacketDefinitionsTests/PacketDefinitionsTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/GameServerConsoleTests/GameServerConsoleTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-AI/LeagueSandbox-AI.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/GameServerConsole/GameServerConsole.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project. [/content/LeagueSandbox-RL-Learning/GameServer.sln]
# /content/LeagueSandbox-RL-Learning/PacketDefinitions420/PacketDefinitions420.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-AI/LeagueSandbox-AI.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3245: Could not resolve this reference. Could not locate the assembly "System". Check to make sure the assembly exists on disk. If this reference is required by your code, you may get compilation errors. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3245: Could not resolve this reference. Could not locate the assembly "System.Core". Check to make sure the assembly exists on disk. If this reference is required by your code, you may get compilation errors. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3245: Could not resolve this reference. Could not locate the assembly "System.Numerics". Check to make sure the assembly exists on disk. If this reference is required by your code, you may get compilation errors. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3243: No way to resolve conflict between "System, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" and "System". Choosing "System, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" arbitrarily. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3243: No way to resolve conflict between "System.Core, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" and "System.Core". Choosing "System.Core, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" arbitrarily. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /usr/share/dotnet/sdk/3.1.404/Microsoft.Common.CurrentVersion.targets(2084,5): warning MSB3243: No way to resolve conflict between "System.Numerics, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" and "System.Numerics". Choosing "System.Numerics, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089" arbitrarily. [/content/LeagueSandbox-RL-Learning/LeaguePackets/LeaguePackets/LeaguePackets.csproj]
# /content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# GameObjects/Monster.cs(13,23): warning CS0108: 'Monster.Name' hides inherited member 'Minion.Name'. Use the new keyword if hiding was intended. [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# GameObjects/AttackableUnits/AI/Champion.cs(237,21): warning CS0108: 'Champion.TeleportTo(float, float)' hides inherited member 'ObjAiBase.TeleportTo(float, float)'. Use the new keyword if hiding was intended. [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(928,25): warning CS0649: Field 'Game.Spell_Action.target_player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(944,26): warning CS0649: Field 'Game.Save_Replay_Info.multiplier' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(922,25): warning CS0649: Field 'Game.Attack_Action.target_player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(908,26): warning CS0649: Field 'Game.Move_Action.x' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(942,27): warning CS0649: Field 'Game.Save_Replay_Info.map' is never assigned to, and will always have its default value null [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(936,25): warning CS0649: Field 'Game.Change_Champion_Command.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(907,25): warning CS0649: Field 'Game.Move_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(915,26): warning CS0649: Field 'Game.Teleport_Action.x' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(929,25): warning CS0649: Field 'Game.Spell_Action.spell_slot' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(937,27): warning CS0649: Field 'Game.Change_Champion_Command.champion_name' is never assigned to, and will always have its default value null [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(943,27): warning CS0649: Field 'Game.Save_Replay_Info.players' is never assigned to, and will always have its default value null [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(916,26): warning CS0649: Field 'Game.Teleport_Action.y' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(921,25): warning CS0649: Field 'Game.Attack_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(931,26): warning CS0649: Field 'Game.Spell_Action.y' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(927,25): warning CS0649: Field 'Game.Spell_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(914,25): warning CS0649: Field 'Game.Teleport_Action.player_id' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(930,26): warning CS0649: Field 'Game.Spell_Action.x' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# Game.cs(909,26): warning CS0649: Field 'Game.Move_Action.y' is never assigned to, and will always have its default value 0 [/content/LeagueSandbox-RL-Learning/GameServerLib/GameServerLib.csproj]
# /content/LeagueSandbox-RL-Learning/PacketDefinitionsTests/PacketDefinitionsTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/GameServerConsoleTests/GameServerConsoleTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/GameServerConsole/GameServerConsole.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/GameServerLibTests/GameServerLibTests.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# /content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj : warning NU1701: Package 'ENetSharpLeague 1.2.1-beta' was restored using '.NETFramework,Version=v4.6.1, .NETFramework,Version=v4.6.2, .NETFramework,Version=v4.7, .NETFramework,Version=v4.7.1, .NETFramework,Version=v4.7.2, .NETFramework,Version=v4.8' instead of the project target framework '.NETCoreApp,Version=v3.0'. This package may not be fully compatible with your project.
# Champions/Ezreal/E.cs(6,7): warning CS0105: The using directive for 'GameServerCore.Domain.GameObjects' appeared previously in this namespace [/content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj]
# Buffs/GangplankE/GangplankE.cs(34,17): warning CS0219: The variable 'time' is assigned but its value is never used [/content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj]
# Buffs/Yasuo/YasuoEBlock.cs(19,23): warning CS0169: The field 'YasuoEBlock._visualBuff' is never used [/content/LeagueSandbox-RL-Learning/Content/LeagueSandbox-Scripts/LeagueSandbox-Scripts.csproj]
#     45 Warning(s)
#     0 Error(s)
#
# Time Elapsed 00:00:28.21
# =

# %% [markdown]
# #### Run GameServer to Generate Configs

# %%
# !cd /content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0/ && \
/content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0/GameServerConsole --redis_port 6379
# Out:
# [2020-11-24 23:08:34,052] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Items, skipping...
# [2020-11-24 23:08:34,066] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Maps, skipping...
# [2020-11-24 23:08:34,066] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Spells, skipping...
# [2020-11-24 23:08:34,066] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Stats, skipping...
# [2020-11-24 23:08:34,068] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain any items, skipping...
# [2020-11-24 23:08:37,027] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Loaded all C# scripts from package: LeagueSandbox-Scripts
# [2020-11-24 23:08:37,027] [1] DEBUG LeagueSandbox.GameServer.Content.ContentManager - Loaded package with name: LeagueSandbox-Scripts
# [2020-11-24 23:08:37,028] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Default does not contain Champions, skipping...
# [2020-11-24 23:08:37,041] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Default does not contain Buffs, skipping...
# [2020-11-24 23:08:37,503] [1] DEBUG LeagueSandbox.GameServer.Content.Package - LeagueSandbox-Default does not have C# scripts, skipping...
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.ContentManager - Loaded package with name: LeagueSandbox-Default
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Champions, skipping...
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Items, skipping...
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Buffs, skipping...
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Maps, skipping...
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Spells, skipping...
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Stats, skipping...
# [2020-11-24 23:08:37,504] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-AI does not contain any items, skipping...
# [2020-11-24 23:08:37,554] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Loaded all C# scripts from package: LeagueSandbox-AI
# [2020-11-24 23:08:37,554] [1] DEBUG LeagueSandbox.GameServer.Content.ContentManager - Loaded package with name: LeagueSandbox-AI
# [2020-11-24 23:08:37,566] [1] DEBUG LeagueSandbox.GameServer.Server - League Sandbox Build 03/31/2087 04:52:58 UTC
# [2020-11-24 23:08:37,566] [1] DEBUG LeagueSandbox.GameServer.Server - Yorick 0.2.0
# [2020-11-24 23:08:37,566] [1] INFO LeagueSandbox.GameServer.Server - Game started on port: 5119
# [2020-11-24 23:08:37,581] [1] INFO LeagueSandbox.GameServer.Game - Loading Config.
# [2020-11-24 23:08:37,598] [1] DEBUG LeagueSandbox.GameServer.Content.Package - LeagueSandbox-Scripts does not contain a navgrid, skipping...
# [2020-11-24 23:08:37,838] [1] INFO LeagueSandbox.GameServer.Game - Add players
# [2020-11-24 23:08:37,838] [1] INFO LeagueSandbox.GameServer.Game - Player Test Added: Ezreal
# [2020-11-24 23:08:37,843] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for Ezreal.
# [2020-11-24 23:08:37,853] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealBasicAttack.
# [2020-11-24 23:08:37,860] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealMysticShot.
# [2020-11-24 23:08:37,864] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealEssenceFlux.
# [2020-11-24 23:08:37,864] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealArcaneShift.
# [2020-11-24 23:08:37,865] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealTrueshotBarrage.
# [2020-11-24 23:08:37,866] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for SummonerHeal.
# [2020-11-24 23:08:37,867] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for SummonerFlash.
# [2020-11-24 23:08:37,868] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for BaseSpell.
# [2020-11-24 23:08:37,868] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:08:37,868] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:08:37,868] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:08:37,868] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:08:37,869] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:08:37,869] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:08:37,869] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:08:37,869] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for Recall.
# [2020-11-24 23:08:37,870] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealMysticShotMissile.
# [2020-11-24 23:08:37,870] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealMysticShotMissile
# [2020-11-24 23:08:37,871] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealArcaneShiftMissile.
# [2020-11-24 23:08:37,871] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealArcaneShiftMissile
# [2020-11-24 23:08:37,872] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealEssenceFluxMissile.
# [2020-11-24 23:08:37,872] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealEssenceFluxMissile
# [2020-11-24 23:08:37,872] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealMysticShotPulseMissile.
# [2020-11-24 23:08:37,873] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealMysticShotPulseMissile
# PLAYER CONFIG: [player1, LeagueSandbox.GameServer.PlayerConfig]
# PLAYER INDEX: player1
# [2020-11-24 23:08:37,879] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Champion Ezreal leveled up to 1
# Unhandled exception. StackExchange.Redis.RedisConnectionException: It was not possible to connect to the redis server(s). UnableToConnect on 127.0.0.1:6379/Interactive, Initializing/NotStarted, last: NONE, origin: BeginConnectAsync, outstanding: 0, last-read: 0s ago, last-write: 0s ago, keep-alive: 60s, state: Connecting, mgr: 10 of 10 available, last-heartbeat: never, global: 5s ago, v: 2.1.58.34321
#    at StackExchange.Redis.ConnectionMultiplexer.ConnectImpl(ConfigurationOptions configuration, TextWriter log) in /_/src/StackExchange.Redis/ConnectionMultiplexer.cs:line 1169
#    at StackExchange.Redis.ConnectionMultiplexer.Connect(ConfigurationOptions configuration, TextWriter log) in /_/src/StackExchange.Redis/ConnectionMultiplexer.cs:line 1037
#    at StackExchange.Redis.ConnectionMultiplexer.Connect(String configuration, TextWriter log) in /_/src/StackExchange.Redis/ConnectionMultiplexer.cs:line 1020
#    at LeagueSandbox.GameServer.Game.Initialize(Config config, PacketServer server) in /content/LeagueSandbox-RL-Learning/GameServerLib/Game.cs:line 155
#    at LeagueSandbox.GameServer.Server.Start() in /content/LeagueSandbox-RL-Learning/GameServerLib/Server.cs:line 47
#    at LeagueSandbox.GameServer.GameServerLauncher..ctor(String serverHost, UInt16 serverPort, String configJson, String blowfishKey, Int32 human_count, Int32 agent_count, Single multiplier, String replay_path, UInt16 redis_port) in /content/LeagueSandbox-RL-Learning/GameServerLib/Program.cs:line 41
#    at LeagueSandbox.GameServerConsole.Program.Main(String[] args) in /content/LeagueSandbox-RL-Learning/GameServerConsole/Program.cs:line 30

# %% [markdown]
# ### PyLoL (from source)

# %%
# !git clone -v https://github.com/MiscellaneousStuff/pylol.git
# !pip3 install -e pylol
# Out:
# Cloning into 'pylol'...
# POST git-upload-pack (215 bytes)
# remote: Enumerating objects: 513, done.
# remote: Counting objects: 100% (513/513), done.
# remote: Compressing objects: 100% (247/247), done.
# remote: Total 513 (delta 366), reused 409 (delta 264), pack-reused 0
# Receiving objects: 100% (513/513), 160.22 KiB | 428.00 KiB/s, done.
# Resolving deltas: 100% (366/366), done.
# Obtaining file:///content/pylol
# Requirement already satisfied: absl-py>=0.1.0 in /usr/local/lib/python3.6/dist-packages (from PyLoL==1.0.0) (0.10.0)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.6/dist-packages (from PyLoL==1.0.0) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from PyLoL==1.0.0) (1.15.0)
# Collecting redis
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 3.3MB/s
# Requirement already satisfied: portpicker in /usr/local/lib/python3.6/dist-packages (from PyLoL==1.0.0) (1.3.1)
# Installing collected packages: redis, PyLoL
#   Running setup.py develop for PyLoL
# Successfully installed PyLoL redis-3.5.3

# %% [markdown]
# ## Test PyLoL

# %% [markdown]
# ### Install Redis Client (Python) and Redis Server (Linux)

# %%
# !pip3 install redis
# !sudo apt-get install redis-server
# Out:
# Requirement already satisfied: redis in /usr/local/lib/python3.6/dist-packages (3.5.3)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libjemalloc1 redis-tools
# Suggested packages:
#   ruby-redis
# The following NEW packages will be installed:
#   libjemalloc1 redis-server redis-tools
# 0 upgraded, 3 newly installed, 0 to remove and 63 not upgraded.
# Need to get 634 kB of archives.
# After this operation, 3,012 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjemalloc1 amd64 3.6.0-11 [82.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 redis-tools amd64 5:4.0.9-1ubuntu0.2 [516 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 redis-server amd64 5:4.0.9-1ubuntu0.2 [35.4 kB]
# Fetched 634 kB in 2s (307 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libjemalloc1.
# (Reading database ... 147615 files and directories currently installed.)
# Preparing to unpack .../libjemalloc1_3.6.0-11_amd64.deb ...
# Unpacking libjemalloc1 (3.6.0-11) ...
# Selecting previously unselected package redis-tools.
# Preparing to unpack .../redis-tools_5%3a4.0.9-1ubuntu0.2_amd64.deb ...
# Unpacking redis-tools (5:4.0.9-1ubuntu0.2) ...
# Selecting previously unselected package redis-server.
# Preparing to unpack .../redis-server_5%3a4.0.9-1ubuntu0.2_amd64.deb ...
# Unpacking redis-server (5:4.0.9-1ubuntu0.2) ...
# Setting up libjemalloc1 (3.6.0-11) ...
# Setting up redis-tools (5:4.0.9-1ubuntu0.2) ...
# Setting up redis-server (5:4.0.9-1ubuntu0.2) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Created symlink /etc/systemd/system/redis.service → /lib/systemd/system/redis-server.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/redis-server.service → /lib/systemd/system/redis-server.service.
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %% [markdown]
# ### Write Config Dirs

# %%
# Only need to write config for GameServer here as we don't use the League Client within Colab environment
# !touch config_dirs.txt
# !printf "/content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0\n" > config_dirs.txt

# %% [markdown]
# ### Run Test

# %% [markdown]
# #### Test PyLoL on Local IP

# %%
# Get local IP
host = !hostname -i
host = host[0]

# Run Client
# !python3 -m pylol.bin.client --max_steps 100 --host $host --agent scripted --config_path "/content/config_dirs.txt"
# Out:
# /content
# GAMESERVER DIR: /content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0/
# CLIENT DIR:
# List of Run Configs: {'Linux': <class 'pylol.run_configs.platforms.Linux'>}
# I1124 23:09:35.181880 140015489845120 lol_env.py:149] Ports used for GameServer and Redis respectively: [20620, 20621]
# Local Base kwargs: {'host': '172.28.0.2', 'human_observer': False, 'players': [Agent(champ='Ezreal', team='BLUE'), Agent(champ='Ezreal', team='PURPLE')], 'map_name': 'Old Summoners Rift', 'cooldowns_enabled': False, 'game_server_dir': '/content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0/', 'client_dir': '', 'client_port': 20620, 'redis_port': 20621}
# kwargs process: {'human_observer': False, 'players': [Agent(champ='Ezreal', team='BLUE'), Agent(champ='Ezreal', team='PURPLE')], 'map_name': 'Old Summoners Rift', 'cooldowns_enabled': False, 'game_server_dir': '/content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0/', 'client_dir': '', 'client_port': 20620, 'redis_port': 20621}
# CONNECTING TO REDIS ON: 172.28.0.2 20621
# REDIS PORT: 20621
# REDIS ARGS: ['redis-server', '--bind', '0.0.0.0', '--port', '20621']
# I1124 23:09:35.188588 140015489845120 lol_env.py:142] Environment is ready.
# 2823:C 24 Nov 23:09:35.188 # oO0OoO0OoO0Oo Redis is starting oO0OoO0OoO0Oo
# 2823:C 24 Nov 23:09:35.188 # Redis version=4.0.9, bits=64, commit=00000000, modified=0, pid=2823, just started
# 2823:C 24 Nov 23:09:35.188 # Configuration loaded
#                 _._
#            _.-``__ ''-._
#       _.-``    `.  `_.  ''-._           Redis 4.0.9 (00000000/0) 64 bit
#   .-`` .-```.  ```\/    _.,_ ''-._
#  (    '      ,       .-`  | `,    )     Running in standalone mode
#  |`-._`-...-` __...-.``-._|'` _.-'|     Port: 20621
#  |    `-._   `._    /     _.-'    |     PID: 2823
#   `-._    `-._  `-./  _.-'    _.-'
#  |`-._`-._    `-.__.-'    _.-'_.-'|
#  |    `-._`-._        _.-'_.-'    |           http://redis.io
#   `-._    `-._`-.__.-'_.-'    _.-'
#  |`-._`-._    `-.__.-'    _.-'_.-'|
#  |    `-._`-._        _.-'_.-'    |
#   `-._    `-._`-.__.-'_.-'    _.-'
#       `-._    `-.__.-'    _.-'
#           `-._        _.-'
#               `-.__.-'
#
# 2823:M 24 Nov 23:09:35.190 # WARNING: The TCP backlog setting of 511 cannot be enforced because /proc/sys/net/core/somaxconn is set to the lower value of 128.
# 2823:M 24 Nov 23:09:35.190 # Server initialized
# 2823:M 24 Nov 23:09:35.190 # WARNING you have Transparent Huge Pages (THP) support enabled in your kernel. This will create latency and memory usage issues with Redis. To fix this issue run the command 'echo never > /sys/kernel/mm/transparent_hugepage/enabled' as root, and add it to your /etc/rc.local in order to retain the setting after a reboot. Redis must be restarted after THP is disabled.
# 2823:M 24 Nov 23:09:35.190 * Ready to accept connections
# [2020-11-24 23:09:35,550] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Items, skipping...
# [2020-11-24 23:09:35,564] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Maps, skipping...
# [2020-11-24 23:09:35,564] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Spells, skipping...
# [2020-11-24 23:09:35,564] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Scripts does not contain Stats, skipping...
# [2020-11-24 23:09:35,566] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain any items, skipping...
# [2020-11-24 23:09:38,487] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Loaded all C# scripts from package: LeagueSandbox-Scripts
# [2020-11-24 23:09:38,487] [1] DEBUG LeagueSandbox.GameServer.Content.ContentManager - Loaded package with name: LeagueSandbox-Scripts
# [2020-11-24 23:09:38,487] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Default does not contain Champions, skipping...
# [2020-11-24 23:09:38,498] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-Default does not contain Buffs, skipping...
# [2020-11-24 23:09:38,923] [1] DEBUG LeagueSandbox.GameServer.Content.Package - LeagueSandbox-Default does not have C# scripts, skipping...
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.ContentManager - Loaded package with name: LeagueSandbox-Default
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Champions, skipping...
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Items, skipping...
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Buffs, skipping...
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Maps, skipping...
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Spells, skipping...
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package LeagueSandbox-AI does not contain Stats, skipping...
# [2020-11-24 23:09:38,924] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-AI does not contain any items, skipping...
# [2020-11-24 23:09:38,974] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Loaded all C# scripts from package: LeagueSandbox-AI
# [2020-11-24 23:09:38,974] [1] DEBUG LeagueSandbox.GameServer.Content.ContentManager - Loaded package with name: LeagueSandbox-AI
# [2020-11-24 23:09:38,987] [1] DEBUG LeagueSandbox.GameServer.Server - League Sandbox Build 03/31/2087 04:52:58 UTC
# [2020-11-24 23:09:38,987] [1] DEBUG LeagueSandbox.GameServer.Server - Yorick 0.2.0
# [2020-11-24 23:09:38,987] [1] INFO LeagueSandbox.GameServer.Server - Game started on port: 20620
# [2020-11-24 23:09:39,004] [1] INFO LeagueSandbox.GameServer.Game - Loading Config.
# [2020-11-24 23:09:39,023] [1] DEBUG LeagueSandbox.GameServer.Content.Package - LeagueSandbox-Scripts does not contain a navgrid, skipping...
# [2020-11-24 23:09:39,249] [1] INFO LeagueSandbox.GameServer.Game - Add players
# [2020-11-24 23:09:39,250] [1] INFO LeagueSandbox.GameServer.Game - Player 1 Added: Ezreal
# [2020-11-24 23:09:39,255] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for Ezreal.
# [2020-11-24 23:09:39,265] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealBasicAttack.
# [2020-11-24 23:09:39,272] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealMysticShot.
# [2020-11-24 23:09:39,276] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealEssenceFlux.
# [2020-11-24 23:09:39,277] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealArcaneShift.
# [2020-11-24 23:09:39,278] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealTrueshotBarrage.
# [2020-11-24 23:09:39,279] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for SummonerFlash.
# [2020-11-24 23:09:39,280] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for SummonerHeal.
# [2020-11-24 23:09:39,281] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for BaseSpell.
# [2020-11-24 23:09:39,281] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,281] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,281] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,282] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,282] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,282] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,282] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,282] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for Recall.
# [2020-11-24 23:09:39,283] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealMysticShotMissile.
# [2020-11-24 23:09:39,283] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealMysticShotMissile
# [2020-11-24 23:09:39,284] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealArcaneShiftMissile.
# [2020-11-24 23:09:39,284] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealArcaneShiftMissile
# [2020-11-24 23:09:39,284] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealEssenceFluxMissile.
# [2020-11-24 23:09:39,285] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealEssenceFluxMissile
# [2020-11-24 23:09:39,285] [1] DEBUG LeagueSandbox.GameServer.Content.Package - Package: LeagueSandbox-Scripts does not contain file for EzrealMysticShotPulseMissile.
# [2020-11-24 23:09:39,286] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealMysticShotPulseMissile
# PLAYER CONFIG: [player1, LeagueSandbox.GameServer.PlayerConfig]
# PLAYER INDEX: player1
# [2020-11-24 23:09:39,293] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Champion Ezreal leveled up to 1
# [2020-11-24 23:09:39,294] [1] INFO LeagueSandbox.GameServer.Game - Player 2 Added: Ezreal
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.BaseSpell
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealMysticShotMissile
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealArcaneShiftMissile
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealEssenceFluxMissile
# [2020-11-24 23:09:39,294] [1] WARN LeagueSandbox.GameServer.Scripting.CSharp.CSharpScriptEngine - Could not find script: Spells.EzrealMysticShotPulseMissile
# PLAYER CONFIG: [player2, LeagueSandbox.GameServer.PlayerConfig]
# PLAYER INDEX: player2
# [2020-11-24 23:09:39,295] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Champion Ezreal leveled up to 1
# `clients_join` == START CLIENT: clients_join
# [2020-11-24 23:09:39,541] [1] INFO LeagueSandbox.GameServer.Game - Game is ready.
# HUMAN COUNT: 0, AGENT COUNT: 2, humanId: -1
# [2020-11-24 23:09:39,544] [1] DEBUG LeagueSandbox.GameServer.Packets.PacketHandlers.HandleSync - Current map: 1
# [2020-11-24 23:09:39,544] [1] WARN LeagueSandbox.GameServer.Packets.PacketHandlers.HandleSync - Client's version (4.20.0.315) does not match server's 4.20.0.315
# [2020-11-24 23:09:39,550] [1] DEBUG LeagueSandbox.GameServer.Packets.PacketHandlers.HandleSpawn - Spawning map
# `game_started` == START CLIENT: game_started
# Running AI agents
# RESETTING PLAYERS
# I1124 23:09:39.575657 140015489845120 lol_env.py:304] Starting episode 1: on Old Summoners Rift
# [2020-11-24 23:09:39,577] [1] DEBUG LeagueSandbox.GameServer.Packets.PacketHandlers.HandleSync - Current map: 1
# [2020-11-24 23:09:39,577] [1] WARN LeagueSandbox.GameServer.Packets.PacketHandlers.HandleSync - Client's version (4.20.0.315) does not match server's 4.20.0.315
# [2020-11-24 23:09:39,577] [1] DEBUG LeagueSandbox.GameServer.Packets.PacketHandlers.HandleSpawn - Spawning map
# [2020-11-24 23:09:39,592] [1] WARN LeagueSandbox.GameServerConsole.Program - Unable to find League of Legends.exe. Check the GameServerSettings.json settings and your League location.
# TELEPORTING 1st PLAYER
# STEP: 1
# STEP: 2
# STEP: 3
# STEP: 4
# STEP: 5
# STEP: 6
# STEP: 7
# STEP: 8
# STEP: 9
# STEP: 10
# STEP: 11
# STEP: 12
# STEP: 13
# STEP: 14
# STEP: 15
# STEP: 16
# STEP: 17
# STEP: 18
# STEP: 19
# STEP: 20
# STEP: 21
# STEP: 22
# STEP: 23
# STEP: 24
# STEP: 25
# STEP: 26
# STEP: 27
# STEP: 28
# [2020-11-24 23:09:43,247] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Before: getGoldFromChamp: 300 Killer: 0 Victim 0
# STEP: 29
# RESETTING PLAYERS
# I1124 23:09:43.344852 140015489845120 lol_env.py:304] Starting episode 2: on Old Summoners Rift
# TELEPORTING 1st PLAYER
# STEP: 30
# STEP: 31
# STEP: 32
# STEP: 33
# STEP: 34
# STEP: 35
# STEP: 36
# STEP: 37
# STEP: 38
# STEP: 39
# STEP: 40
# STEP: 41
# STEP: 42
# STEP: 43
# STEP: 44
# STEP: 45
# STEP: 46
# STEP: 47
# STEP: 48
# STEP: 49
# STEP: 50
# STEP: 51
# STEP: 52
# STEP: 53
# STEP: 54
# STEP: 55
# STEP: 56
# STEP: 57
# STEP: 58
# [2020-11-24 23:09:47,251] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Before: getGoldFromChamp: 274.5 Killer: 1 Victim -1
# [2020-11-24 23:09:47,252] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Before: getGoldFromChamp: 349.5 Killer: -2 Victim 2
# STEP: 59
# RESETTING PLAYERS
# I1124 23:09:47.351229 140015489845120 lol_env.py:304] Starting episode 3: on Old Summoners Rift
# TELEPORTING 1st PLAYER
# STEP: 60
# STEP: 61
# STEP: 62
# STEP: 63
# STEP: 64
# STEP: 65
# STEP: 66
# STEP: 67
# STEP: 68
# STEP: 69
# STEP: 70
# STEP: 71
# STEP: 72
# STEP: 73
# STEP: 74
# STEP: 75
# STEP: 76
# STEP: 77
# STEP: 78
# STEP: 79
# STEP: 80
# STEP: 81
# STEP: 82
# STEP: 83
# STEP: 84
# STEP: 85
# STEP: 86
# STEP: 87
# STEP: 88
# STEP: 89
# STEP: 90
# STEP: 91
# STEP: 92
# STEP: 93
# [2020-11-24 23:09:51,895] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Before: getGoldFromChamp: 300 Killer: -1 Victim 1
# [2020-11-24 23:09:51,895] [1] DEBUG LeagueSandbox.GameServer.GameObjects.AttackableUnits.AttackableUnit - Before: getGoldFromChamp: 300 Killer: -1 Victim 1
# STEP: 94
# RESETTING PLAYERS
# I1124 23:09:52.023206 140015489845120 lol_env.py:304] Starting episode 4: on Old Summoners Rift
# TELEPORTING 1st PLAYER
# STEP: 95
# STEP: 96
# RESETTING PLAYERS
# I1124 23:09:52.287174 140015489845120 lol_env.py:304] Starting episode 5: on Old Summoners Rift
# TELEPORTING 1st PLAYER
# STEP: 97
# STEP: 98
# STEP: 99
# STEP: 100
# Took 13.364 seconds for 100 steps: 7.483 fps
# save_replay data: False
# REPLAY DATA FROM GAMESERVER: 202 {
#   "info": {
#     "map": "Old Summoners Rift",
#     "players": "Ezreal.BLUE,Ezreal.PURPLE",
#     "multiplier": 7.5
#   },
#   "actions": [
#     {
#       "game_time": 33.4341,
#       "action_type": "reset",
#       "action_data": ""
#     },
#     {
#       "game_time": 33.4341,
#       "action_type": "teleport",
#       "action_data": "{\"player_id\": \"1\", \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 33.4341,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 13927.0, \"y\": 14175.0}"
#     },
#     {
#       "game_time": 33.4341,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 26.0, \"y\": 280.0}"
#     },
#     {
#       "game_time": 293.9157,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 293.9157,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 293.9157,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 293.9157,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 555.5945,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 555.5945,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 555.5945,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 555.5945,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 821.8952,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 821.8952,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 821.8952,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 821.8952,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1082.8696,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1082.8696,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1082.8696,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1082.8696,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1213.9778,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1213.9778,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1345.0764,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1345.0764,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1737.2416,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1868.7859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1868.7859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1868.7859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1868.7859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1868.7859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 1868.7859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 1868.7859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 2138.829,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 2138.829,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 2138.829,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 2138.829,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 2534.0686,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 2534.0686,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 2534.0686,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 2534.0686,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 2534.0686,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 2534.0686,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 2697.7903,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 2697.7903,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 2960.4624,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3222.6606,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3354.2366,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3486.442,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3486.442,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3486.442,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3617.7449,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3880.8455,
#       "action_type": "reset",
#       "action_data": ""
#     },
#     {
#       "game_time": 3880.8455,
#       "action_type": "teleport",
#       "action_data": "{\"player_id\": \"1\", \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 3880.8455,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 3880.8455,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 4145.28,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 4145.28,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 4145.28,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 4145.28,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 4408.9893,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 4408.9893,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 4540.0127,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 4540.0127,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5096.3896,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5227.8745,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5227.8745,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5490.181,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5621.992,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5621.992,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5621.992,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5621.992,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5621.992,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5883.8154,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5883.8154,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 5883.8154,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 5883.8154,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 6147.046,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 6147.046,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 6147.046,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 6147.046,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 6410.5264,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 6410.5264,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 6410.5264,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 6410.5264,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 6804.407,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 6804.407,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 6804.407,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 6804.407,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 6804.407,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 6804.407,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 7067.0786,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 7067.0786,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 7067.0786,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 7067.0786,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 7361.4165,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 7361.4165,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 7361.4165,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 7361.4165,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 7623.423,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 7623.423,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 7623.423,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 7623.423,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 7886.5854,
#       "action_type": "reset",
#       "action_data": ""
#     },
#     {
#       "game_time": 8018.9214,
#       "action_type": "teleport",
#       "action_data": "{\"player_id\": \"1\", \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8150.0913,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8150.0913,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8150.0913,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8150.0913,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 6350.0, \"y\": 6350.0}"
#     },
#     {
#       "game_time": 8150.0913,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8150.0913,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8675.584,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8937.895,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8937.895,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 8937.895,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 8937.895,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 9365.877,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 9365.877,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 9365.877,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 9365.877,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 9365.877,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 9365.877,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 9629.317,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 9629.317,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 9891.43,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 9891.43,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 9891.43,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 9891.43,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10023.859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10023.859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10023.859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10023.859,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10155.945,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10155.945,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10419.983,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10419.983,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10419.983,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10419.983,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10685.833,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10948.434,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10948.434,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10948.434,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10948.434,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10948.434,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 10948.434,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 10948.434,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 11342.034,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 11342.034,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 11342.034,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 11342.034,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 11342.034,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 11342.034,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 11605.15,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 11605.15,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 11605.15,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 11605.15,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12000.662,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12000.662,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12000.662,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12000.662,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12000.662,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12000.662,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12557.773,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "reset",
#       "action_data": ""
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "teleport",
#       "action_data": "{\"player_id\": \"1\", \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "reset",
#       "action_data": ""
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "teleport",
#       "action_data": "{\"player_id\": \"1\", \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12821.212,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 12951.271,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 12951.271,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 13081.971,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 13081.971,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     },
#     {
#       "game_time": 13343.723,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"1\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7650.0, \"y\": 7650.0}"
#     },
#     {
#       "game_time": 13343.723,
#       "action_type": "spell",
#       "action_data": "{\"player_id\": \"2\", \"target_player_id\": \"2\", \"spell_slot\": 0, \"x\": 7500.0, \"y\": 7500.0}"
#     }
#   ]
# }
# REPLAY JSON (b'command_data', b'{\n  "info": {\n    "map": "Old Summoners Rift",\n    "players": "Ezreal.BLUE,Ezreal.PURPLE",\n    "multiplier": 7.5\n  },\n  "actions": [\n    {\n      "game_time": 33.4341,\n      "action_type": "reset",\n      "action_data": ""\n    },\n    {\n      "game_time": 33.4341,\n      "action_type": "teleport",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 33.4341,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 13927.0, \\"y\\": 14175.0}"\n    },\n    {\n      "game_time": 33.4341,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 26.0, \\"y\\": 280.0}"\n    },\n    {\n      "game_time": 293.9157,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7650.0, \\"y\\": 7650.0}"\n    },\n    {\n      "game_time": 293.9157,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 293.9157,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7650.0, \\"y\\": 7650.0}"\n    },\n    {\n      "game_time": 293.9157,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 555.5945,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7650.0, \\"y\\": 7650.0}"\n    },\n    {\n      "game_time": 555.5945,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 555.5945,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7650.0, \\"y\\": 7650.0}"\n    },\n    {\n      "game_time": 555.5945,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 821.8952,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7650.0, \\"y\\": 7650.0}"\n    },\n    {\n      "game_time": 821.8952,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 821.8952,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7650.0, \\"y\\": 7650.0}"\n    },\n    {\n      "game_time": 821.8952,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 1082.8696,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7650.0, \\"y\\": 7650.0}"\n    },\n    {\n      "game_time": 1082.8696,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"2\\", \\"target_player_id\\": \\"2\\", \\"spell_slot\\": 0, \\"x\\": 7500.0, \\"y\\": 7500.0}"\n    },\n    {\n      "game_time": 1082.8696,\n      "action_type": "spell",\n      "action_data": "{\\"player_id\\": \\"1\\", \\"targe ...
# I1124 23:09:53.201374 140015489845120 lol_env.py:316] Wrote replay to: /content/LeagueSandbox-RL-Learning/GameServerConsole/bin/Debug/netcoreapp3.0/Replays/ScriptedAgent/Old_Summoners_Rift_2020-11-24-23-09-53-ee291506-d945-4efb-bf61-1f0b6e958e17.json
# I1124 23:09:53.201865 140015489845120 lol_env.py:212] Environment Close
# I1124 23:09:53.302404 140015489845120 lol_process.py:139] Shutdown gracefully.
# I1124 23:09:53.302621 140015489845120 lol_process.py:123] Shutdown with return code: 143
# I1124 23:09:53.303298 140015489845120 lol_env.py:212] Environment Close
# I1124 23:09:53.303452 140015489845120 portpicker.py:85] Returning a port that wasn't given by portpicker: 20620
# I1124 23:09:53.303537 140015489845120 portpicker.py:85] Returning a port that wasn't given by portpicker: 20621

# %% [markdown]
# ## Training
#
# Now you are all set to start training with PyLoL. Execute cell below and look for **RMe** in the log statistics - mean episode rewards. In about x minutes you should start seeing the agent achieve better results.
